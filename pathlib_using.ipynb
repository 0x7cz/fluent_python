# %% [markdown]
# pathlib的好处:相比os.path更加方便,os.path还是面向过程的思维:返回的是一个str.
# https://docs.python.org/3/library/pathlib.html

# %%
from pathlib import Path

# %%
p = Path('.')
[x for x in p.iterdir()]
for i in p.glob('*.py'):
    print(i)
a = p/'1.txt'
a.exists()
# Out:
# test.py
# unit.py
# False
